# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Users/nguyentienhuy/Documents/SRH/CaseStudy/Data/arxiv_data/arxiv-metadata-oai-snapshot.json'

import pandas as pd

# Replace 'path_to_your_file.json' with the path to your JSON file
json_file_path = '/Users/nguyentienhuy/Documents/SRH/CaseStudy/Data/arxiv_data/arxiv-metadata-oai-snapshot.json'

# Load the JSON file into a DataFrame
df = pd.read_json(json_file_path, lines=True)

# Now df holds the contents of your JSON file as a DataFrame

# %%
df
# Out:
#                        id           submitter  \
# 0               0704.0001      Pavel Nadolsky
# 1               0704.0002        Louis Theran
# 2               0704.0003         Hongjun Pan
# 3               0704.0004        David Callan
# 4               0704.0005  Alberto Torchinsky
# ...                   ...                 ...
# 2421961  supr-con/9608008     Ruslan Prozorov
# 2421962  supr-con/9609001  Durga P. Choudhury
# 2421963  supr-con/9609002  Durga P. Choudhury
# 2421964  supr-con/9609003   Hasegawa Yasumasa
# 2421965  supr-con/9609004    Masanori Ichioka
#
#                                                    authors  \
# 0        C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                          Ileana Streinu and Louis Theran
# 2                                              Hongjun Pan
# 3                                             David Callan
# 4                 Wael Abu-Shammala and Alberto Torchinsky
# ...

# %%
df2 = df[['id', 'authors', 'title', 'abstract']]

# %%
df2.rename(columns={'id': 'ID', 'authors': 'Authors', 'title': 'Title', 'abstract': 'Abstract'}, inplace=True)
# Out:
# /Users/nguyentienhuy/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df2
# Out:
#                        ID                                            Authors  \
# 0               0704.0001  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1               0704.0002                    Ileana Streinu and Louis Theran
# 2               0704.0003                                        Hongjun Pan
# 3               0704.0004                                       David Callan
# 4               0704.0005           Wael Abu-Shammala and Alberto Torchinsky
# ...                   ...                                                ...
# 2421961  supr-con/9608008  R. Prozorov, M. Konczykowski, B. Schmidt, Y. Y...
# 2421962  supr-con/9609001  Durga P. Choudhury, Balam A. Willemsen, John S...
# 2421963  supr-con/9609002  Balam A. Willemsen, J. S. Derov and S.Sridhar ...
# 2421964  supr-con/9609003  Yasumasa Hasegawa (Himeji Institute of Technol...
# 2421965  supr-con/9609004  Naoki Enomoto, Masanori Ichioka and Kazushige ...
#
# ...

# %%
pip install reportlab
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.platypus import SimpleDocTemplate, Paragraph
from xml.sax.saxutils import escape

# Define the source directory containing text files and the destination directory for PDFs
source_dir = '/Users/nguyentienhuy/Documents/SRH/CaseStudy/Data/arxiv_data/Data_arxiv'
destination_dir = '/Users/nguyentienhuy/Documents/SRH/CaseStudy/Data/arxiv_data/Data_arxiv_pdf'

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

# Get a sample style sheet
styles = getSampleStyleSheet()

# Function to convert a text file to a PDF
# def text_to_pdf(text_file, pdf_file):
#     doc = SimpleDocTemplate(pdf_file, pagesize=letter)
#     story = []
#     style = styles['Normal']

#     # Open the text file and add its content to the story
#     with open(text_file, 'r') as file:
#         for line in file:
#             # Remove leading/trailing whitespace and add a line break
#             line = line.strip()
#             if line:
#                 paragraph = Paragraph(line, style)
#                 story.append(paragraph)

def text_to_pdf(text_file, pdf_file):
    doc = SimpleDocTemplate(pdf_file, pagesize=letter)
    story = []
    style = styles['Normal']

    # Open the text file and add its content to the story
    with open(text_file, 'r') as file:
        for line in file:
            # Remove leading/trailing whitespace
            line = line.strip()
            if line:
                # Escape XML/HTML special characters to avoid parsing them as markup
                line = escape(line)
                paragraph = Paragraph(line, style)
                story.append(paragraph)

    # Build the PDF
    doc.build(story)

# Loop through all text files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith('.txt'):
        base_name = os.path.splitext(file_name)[0]
        pdf_file_name = f"{base_name}.pdf"
        pdf_file_path = os.path.join(destination_dir, pdf_file_name)
        text_file_path = os.path.join(source_dir, file_name)
        
        # Convert the text file to a PDF
        text_to_pdf(text_file_path, pdf_file_path)

print("Conversion completed.")
# Out:
# Conversion completed.
